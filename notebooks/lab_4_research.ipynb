# %%
import os
os.environ["OPENBLAS_NUM_THREADS"] = "1"  # For implicit ALS

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import nmslib

from implicit.als import AlternatingLeastSquares

from rectools.metrics import Precision, Recall, MAP, calc_metrics
from rectools.models import PopularModel, RandomModel, ImplicitALSWrapperModel
from rectools import Columns
from rectools.dataset import Dataset, Interactions
from rectools.models import ImplicitALSWrapperModel, LightFMWrapperModel
from rectools.model_selection import TimeRangeSplitter

import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.pyplot as plt
from pathlib import Path
import typing as tp
from tqdm import tqdm

from lightfm import LightFM

from implicit.bpr import BayesianPersonalizedRanking
from implicit.lmf import LogisticMatrixFactorization

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# # Load Data

# %%
users = pd.read_csv('data_original/users.csv')
items = pd.read_csv('data_original/items.csv')
interactions = pd.read_csv('data_original/interactions.csv')

users.fillna('Unknown', inplace=True)

# %% [markdown]
# # Preprocess

# %%
interactions.drop(interactions[interactions['last_watch_dt'].str.len() != 10].index, inplace=True)
interactions[Columns.Datetime] = pd.to_datetime(interactions['last_watch_dt'], format='%Y-%m-%d')
max_date = interactions[Columns.Datetime].max()
interactions = interactions[interactions.watched_pct > 0]
interactions[Columns.Weight] = np.where(interactions['watched_pct'] > 10, 5, 1) # MB drop 0 pct

interactions = Interactions(interactions)
interactions.df.head()
# Out:
#    user_id  item_id last_watch_dt  total_dur  watched_pct   datetime  weight
# 0   176549     9506    2021-05-11       4250         72.0 2021-05-11     5.0
# 1   699317     1659    2021-05-29       8317        100.0 2021-05-29     5.0
# 3   864613     7638    2021-07-05      14483        100.0 2021-07-05     5.0
# 4   964868     9506    2021-04-30       6725        100.0 2021-04-30     5.0
# 5  1032142     6686    2021-05-13      11286        100.0 2021-05-13     5.0

# %%
metrics_name = {
    'Precision': Precision,
    'Recall': Recall,
    'MAP': MAP,
}

metrics = {}
for metric_name, metric in metrics_name.items():
    for k in [1, 5, 10]:
        metrics[f'{metric_name}@{k}'] = metric(k=k)
metrics
# Out:
# {'Precision@1': Precision(k=1),
#  'Precision@5': Precision(k=5),
#  'Precision@10': Precision(k=10),
#  'Recall@1': Recall(k=1),
#  'Recall@5': Recall(k=5),
#  'Recall@10': Recall(k=10),
#  'MAP@1': MAP(k=1, divide_by_k=False),
#  'MAP@5': MAP(k=5, divide_by_k=False),
#  'MAP@10': MAP(k=10, divide_by_k=False)}

# %%
K_RECOS = 10
RANDOM_STATE = 42
NUM_THREADS = 24
N_FACTORS = (64, 128, 256)

N_EPOCHS = [3, 5, 7] # Lightfm
USER_ALPHA = 0 # Lightfm
ITEM_ALPHA = 0 # Lightfm
LEARNING_RATE = [0.5, 0.1, 0.01] # Lightfm

N_SPLITS = 3
TEST_SIZE = '7D'

# %%
models = {
    'popular': PopularModel(),
}
implicit_models = {
    'ALS': AlternatingLeastSquares,
}
lightfm_losses = ('logistic', 'bpr', 'warp')

for implicit_name, implicit_model in implicit_models.items():
    for n_factors in N_FACTORS:
        for n_epochs in N_EPOCHS:
            models[f"{implicit_name}_{n_factors}_{n_epochs}"] = (
                ImplicitALSWrapperModel(
                    model=implicit_model(
                        factors=n_factors, 
                        random_state=RANDOM_STATE, 
                        num_threads=NUM_THREADS,
                        use_gpu=True,
                        iterations=n_epochs
                    ),
                    fit_features_together=True,
                )
            )

for loss in lightfm_losses:
    for n_factors in N_FACTORS:
        for n_epochs in N_EPOCHS:
            for lr in LEARNING_RATE:
                models[f"LightFM_{loss}_{n_factors}_{n_epochs}_{lr}"] = LightFMWrapperModel(
                    LightFM(
                        no_components=n_factors, 
                        loss=loss, 
                        random_state=RANDOM_STATE,
                        learning_rate=lr,
                        user_alpha=USER_ALPHA,
                        item_alpha=ITEM_ALPHA,
                    ),
                    epochs=n_epochs,
                    num_threads=NUM_THREADS,
                )

models
# Out:
# {'popular': <rectools.models.popular.PopularModel at 0x7f32916e7ac0>,
#  'ALS_64_3': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7f32916e7af0>,
#  'ALS_64_5': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7f32916e7220>,
#  'ALS_64_7': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7f32916e54b0>,
#  'ALS_128_3': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7f32916e5510>,
#  'ALS_128_5': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7f32916e6b00>,
#  'ALS_128_7': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7f32916e7cd0>,
#  'ALS_256_3': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7f32916e7d60>,
#  'ALS_256_5': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7f32916e7df0>,
#  'ALS_256_7': <rectools.models.implicit_als.ImplicitALSWrapperModel at 0x7f32916e7e80>,
#  'LightFM_logistic_64_3_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32916e7fd0>,
#  'LightFM_logistic_64_3_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32916e7b20>,
#  'LightFM_logistic_64_3_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32916e7940>,
#  'LightFM_logistic_64_5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32916e74c0>,
#  'LightFM_logistic_64_5_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32916e76a0>,
#  'LightFM_logistic_64_5_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32916e56f0>,
#  'LightFM_logistic_64_7_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32f50e1570>,
#  'LightFM_logistic_64_7_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32f50e0c70>,
#  'LightFM_logistic_64_7_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32ec653f70>,
#  'LightFM_logistic_128_3_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32ec652ce0>,
#  'LightFM_logistic_128_3_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32ec652d10>,
#  'LightFM_logistic_128_3_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32ec6533a0>,
#  'LightFM_logistic_128_5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32ec653220>,
#  'LightFM_logistic_128_5_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f32f5137d00>,
#  'LightFM_logistic_128_5_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60100>,
#  'LightFM_logistic_128_7_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d601c0>,
#  'LightFM_logistic_128_7_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60280>,
#  'LightFM_logistic_128_7_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60340>,
#  'LightFM_logistic_256_3_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60400>,
#  'LightFM_logistic_256_3_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d604c0>,
#  'LightFM_logistic_256_3_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60580>,
#  'LightFM_logistic_256_5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60640>,
#  'LightFM_logistic_256_5_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60700>,
#  'LightFM_logistic_256_5_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d607c0>,
#  'LightFM_logistic_256_7_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60880>,
#  'LightFM_logistic_256_7_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60940>,
#  'LightFM_logistic_256_7_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60a00>,
#  'LightFM_bpr_64_3_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60ac0>,
#  'LightFM_bpr_64_3_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60b80>,
#  'LightFM_bpr_64_3_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60c40>,
#  'LightFM_bpr_64_5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60d00>,
#  'LightFM_bpr_64_5_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60dc0>,
#  'LightFM_bpr_64_5_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60e80>,
#  'LightFM_bpr_64_7_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d60f40>,
#  'LightFM_bpr_64_7_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61000>,
#  'LightFM_bpr_64_7_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d610c0>,
#  'LightFM_bpr_128_3_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61180>,
#  'LightFM_bpr_128_3_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61240>,
#  'LightFM_bpr_128_3_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61300>,
#  'LightFM_bpr_128_5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d613c0>,
#  'LightFM_bpr_128_5_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61480>,
#  'LightFM_bpr_128_5_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61540>,
#  'LightFM_bpr_128_7_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61600>,
#  'LightFM_bpr_128_7_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d616c0>,
#  'LightFM_bpr_128_7_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61780>,
#  'LightFM_bpr_256_3_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61840>,
#  'LightFM_bpr_256_3_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61900>,
#  'LightFM_bpr_256_3_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d619c0>,
#  'LightFM_bpr_256_5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61a80>,
#  'LightFM_bpr_256_5_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61b40>,
#  'LightFM_bpr_256_5_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61c00>,
#  'LightFM_bpr_256_7_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61cc0>,
#  'LightFM_bpr_256_7_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61d80>,
#  'LightFM_bpr_256_7_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61e40>,
#  'LightFM_warp_64_3_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61f00>,
#  'LightFM_warp_64_3_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d61fc0>,
#  'LightFM_warp_64_3_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62080>,
#  'LightFM_warp_64_5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62140>,
#  'LightFM_warp_64_5_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62200>,
#  'LightFM_warp_64_5_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d622c0>,
#  'LightFM_warp_64_7_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62380>,
#  'LightFM_warp_64_7_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62440>,
#  'LightFM_warp_64_7_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62500>,
#  'LightFM_warp_128_3_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d625c0>,
#  'LightFM_warp_128_3_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62680>,
#  'LightFM_warp_128_3_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62740>,
#  'LightFM_warp_128_5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62800>,
#  'LightFM_warp_128_5_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d628c0>,
#  'LightFM_warp_128_5_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62980>,
#  'LightFM_warp_128_7_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62a40>,
#  'LightFM_warp_128_7_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62b00>,
#  'LightFM_warp_128_7_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62bc0>,
#  'LightFM_warp_256_3_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62c80>,
#  'LightFM_warp_256_3_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62d40>,
#  'LightFM_warp_256_3_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62e00>,
#  'LightFM_warp_256_5_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62ec0>,
#  'LightFM_warp_256_5_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d62f80>,
#  'LightFM_warp_256_5_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d63040>,
#  'LightFM_warp_256_7_0.5': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d63100>,
#  'LightFM_warp_256_7_0.1': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d631c0>,
#  'LightFM_warp_256_7_0.01': <rectools.models.lightfm.LightFMWrapperModel at 0x7f3290d63280>}

# %% [markdown]
# # CV

# %%
cv = TimeRangeSplitter(
    test_size=TEST_SIZE,
    n_splits=N_SPLITS,
    filter_already_seen=True,
    filter_cold_items=True,
    filter_cold_users=True,
)

fold_iterator = cv.split(interactions, collect_fold_stats=True)

# %%
# %%time
results = []

for i_fold, (train_ids, test_ids, fold_info) in enumerate(fold_iterator):
    # TrainTest split
    train = interactions.df.iloc[train_ids].copy()
    
    test = interactions.df.iloc[test_ids][Columns.UserItem].copy()

    # Users feature
    users_fold = users.loc[users[Columns.User].isin(train[Columns.User])].copy()
    user_features_frames = []
    for feature in ["sex", "age", "income"]:
        feature_frame = users_fold.reindex(columns=[Columns.User, feature])
        feature_frame.columns = ["id", "value"]
        feature_frame["feature"] = feature
        user_features_frames.append(feature_frame)
    user_features = pd.concat(user_features_frames)

    # Items feature
    items_fold = items.loc[items[Columns.Item].isin(train[Columns.Item])].copy()
    # Explode genres to flatten table
    items_fold["genre"] = items_fold["genres"].str.lower().str.replace(", ", ",", regex=False).str.split(",")
    genre_feature = items_fold[["item_id", "genre"]].explode("genre")
    genre_feature.columns = ["id", "value"]
    genre_feature["feature"] = "genre"

    content_feature = items_fold.reindex(columns=[Columns.Item, "content_type"])
    content_feature.columns = ["id", "value"]
    content_feature["feature"] = "content_type"
    item_features = pd.concat((genre_feature, content_feature))

    dataset = Dataset.construct(
        interactions_df=train,
        user_features_df=user_features,
        cat_user_features=["sex", "age", "income"],
        item_features_df=item_features,
        cat_item_features=["genre", "content_type"],
    )
    TEST_USERS = test[Columns.User].unique()

    for model_name, model in models.items():
        print(f"Fitting model {model_name}...")
        model_quality = {'model': model_name, "fold": i_fold}

        model.fit(dataset)
        recos = model.recommend(
            users=TEST_USERS,
            dataset=dataset,
            k=K_RECOS,
            filter_viewed=True,
        )
        metric_values = calc_metrics(metrics, recos, test, train)
        model_quality.update(metric_values)
        results.append(model_quality)
# Out:
# Fitting model popular...
# Fitting model ALS_64_3...
# Fitting model ALS_64_5...
# Fitting model ALS_64_7...
# Fitting model ALS_128_3...
# Fitting model ALS_128_5...
# Fitting model ALS_128_7...
# Fitting model ALS_256_3...
# Fitting model ALS_256_5...
# Fitting model ALS_256_7...
# Fitting model LightFM_logistic_64_3_0.5...
# Fitting model LightFM_logistic_64_3_0.1...
# Fitting model LightFM_logistic_64_3_0.01...
# Fitting model LightFM_logistic_64_5_0.5...
# Fitting model LightFM_logistic_64_5_0.1...
# Fitting model LightFM_logistic_64_5_0.01...
# Fitting model LightFM_logistic_64_7_0.5...
# Fitting model LightFM_logistic_64_7_0.1...
# Fitting model LightFM_logistic_64_7_0.01...
# Fitting model LightFM_logistic_128_3_0.5...
# Fitting model LightFM_logistic_128_3_0.1...
# Fitting model LightFM_logistic_128_3_0.01...
# Fitting model LightFM_logistic_128_5_0.5...
# Fitting model LightFM_logistic_128_5_0.1...
# Fitting model LightFM_logistic_128_5_0.01...
# Fitting model LightFM_logistic_128_7_0.5...
# Fitting model LightFM_logistic_128_7_0.1...
# Fitting model LightFM_logistic_128_7_0.01...
# Fitting model LightFM_logistic_256_3_0.5...
# Fitting model LightFM_logistic_256_3_0.1...
# Fitting model LightFM_logistic_256_3_0.01...
# Fitting model LightFM_logistic_256_5_0.5...
# Fitting model LightFM_logistic_256_5_0.1...
# Fitting model LightFM_logistic_256_5_0.01...
# Fitting model LightFM_logistic_256_7_0.5...
# Fitting model LightFM_logistic_256_7_0.1...
# Fitting model LightFM_logistic_256_7_0.01...
# Fitting model LightFM_bpr_64_3_0.5...
# Fitting model LightFM_bpr_64_3_0.1...
# Fitting model LightFM_bpr_64_3_0.01...
# Fitting model LightFM_bpr_64_5_0.5...
# Fitting model LightFM_bpr_64_5_0.1...
# Fitting model LightFM_bpr_64_5_0.01...
# Fitting model LightFM_bpr_64_7_0.5...
# Fitting model LightFM_bpr_64_7_0.1...
# Fitting model LightFM_bpr_64_7_0.01...
# Fitting model LightFM_bpr_128_3_0.5...
# Fitting model LightFM_bpr_128_3_0.1...
# Fitting model LightFM_bpr_128_3_0.01...
# Fitting model LightFM_bpr_128_5_0.5...
# Fitting model LightFM_bpr_128_5_0.1...
# Fitting model LightFM_bpr_128_5_0.01...
# Fitting model LightFM_bpr_128_7_0.5...
# Fitting model LightFM_bpr_128_7_0.1...
# Fitting model LightFM_bpr_128_7_0.01...
# Fitting model LightFM_bpr_256_3_0.5...
# Fitting model LightFM_bpr_256_3_0.1...
# Fitting model LightFM_bpr_256_3_0.01...
# Fitting model LightFM_bpr_256_5_0.5...
# Fitting model LightFM_bpr_256_5_0.1...
# Fitting model LightFM_bpr_256_5_0.01...
# Fitting model LightFM_bpr_256_7_0.5...
# Fitting model LightFM_bpr_256_7_0.1...
# Fitting model LightFM_bpr_256_7_0.01...
# Fitting model LightFM_warp_64_3_0.5...
# Fitting model LightFM_warp_64_3_0.1...
# Fitting model LightFM_warp_64_3_0.01...
# Fitting model LightFM_warp_64_5_0.5...
# Fitting model LightFM_warp_64_5_0.1...
# Fitting model LightFM_warp_64_5_0.01...
# Fitting model LightFM_warp_64_7_0.5...
# Fitting model LightFM_warp_64_7_0.1...
# Fitting model LightFM_warp_64_7_0.01...
# Fitting model LightFM_warp_128_3_0.5...
# Fitting model LightFM_warp_128_3_0.1...
# Fitting model LightFM_warp_128_3_0.01...
# Fitting model LightFM_warp_128_5_0.5...
# Fitting model LightFM_warp_128_5_0.1...
# Fitting model LightFM_warp_128_5_0.01...
# Fitting model LightFM_warp_128_7_0.5...
# Fitting model LightFM_warp_128_7_0.1...
# Fitting model LightFM_warp_128_7_0.01...
# Fitting model LightFM_warp_256_3_0.5...
# Fitting model LightFM_warp_256_3_0.1...
# Fitting model LightFM_warp_256_3_0.01...
# Fitting model LightFM_warp_256_5_0.5...
# Fitting model LightFM_warp_256_5_0.1...
# Fitting model LightFM_warp_256_5_0.01...
# Fitting model LightFM_warp_256_7_0.5...
# Fitting model LightFM_warp_256_7_0.1...
# Fitting model LightFM_warp_256_7_0.01...
# Fitting model popular...
# Fitting model ALS_64_3...
# Fitting model ALS_64_5...
# Fitting model ALS_64_7...
# Fitting model ALS_128_3...
# Fitting model ALS_128_5...
# Fitting model ALS_128_7...
# Fitting model ALS_256_3...
# Fitting model ALS_256_5...
# Fitting model ALS_256_7...
# Fitting model LightFM_logistic_64_3_0.5...
# Fitting model LightFM_logistic_64_3_0.1...
# Fitting model LightFM_logistic_64_3_0.01...
# Fitting model LightFM_logistic_64_5_0.5...
# Fitting model LightFM_logistic_64_5_0.1...
# Fitting model LightFM_logistic_64_5_0.01...
# Fitting model LightFM_logistic_64_7_0.5...
# Fitting model LightFM_logistic_64_7_0.1...
# Fitting model LightFM_logistic_64_7_0.01...
# Fitting model LightFM_logistic_128_3_0.5...
# Fitting model LightFM_logistic_128_3_0.1...
# Fitting model LightFM_logistic_128_3_0.01...
# Fitting model LightFM_logistic_128_5_0.5...
# Fitting model LightFM_logistic_128_5_0.1...
# Fitting model LightFM_logistic_128_5_0.01...
# Fitting model LightFM_logistic_128_7_0.5...
# Fitting model LightFM_logistic_128_7_0.1...
# Fitting model LightFM_logistic_128_7_0.01...
# Fitting model LightFM_logistic_256_3_0.5...
# Fitting model LightFM_logistic_256_3_0.1...
# Fitting model LightFM_logistic_256_3_0.01...
# Fitting model LightFM_logistic_256_5_0.5...
# Fitting model LightFM_logistic_256_5_0.1...
# Fitting model LightFM_logistic_256_5_0.01...
# Fitting model LightFM_logistic_256_7_0.5...
# Fitting model LightFM_logistic_256_7_0.1...
# Fitting model LightFM_logistic_256_7_0.01...
# Fitting model LightFM_bpr_64_3_0.5...
# Fitting model LightFM_bpr_64_3_0.1...
# Fitting model LightFM_bpr_64_3_0.01...
# Fitting model LightFM_bpr_64_5_0.5...
# Fitting model LightFM_bpr_64_5_0.1...
# Fitting model LightFM_bpr_64_5_0.01...
# Fitting model LightFM_bpr_64_7_0.5...
# Fitting model LightFM_bpr_64_7_0.1...
# Fitting model LightFM_bpr_64_7_0.01...
# Fitting model LightFM_bpr_128_3_0.5...
# Fitting model LightFM_bpr_128_3_0.1...
# Fitting model LightFM_bpr_128_3_0.01...
# Fitting model LightFM_bpr_128_5_0.5...
# Fitting model LightFM_bpr_128_5_0.1...
# Fitting model LightFM_bpr_128_5_0.01...
# Fitting model LightFM_bpr_128_7_0.5...
# Fitting model LightFM_bpr_128_7_0.1...
# Fitting model LightFM_bpr_128_7_0.01...
# Fitting model LightFM_bpr_256_3_0.5...
# Fitting model LightFM_bpr_256_3_0.1...
# Fitting model LightFM_bpr_256_3_0.01...
# Fitting model LightFM_bpr_256_5_0.5...
# Fitting model LightFM_bpr_256_5_0.1...
# Fitting model LightFM_bpr_256_5_0.01...
# Fitting model LightFM_bpr_256_7_0.5...
# Fitting model LightFM_bpr_256_7_0.1...
# Fitting model LightFM_bpr_256_7_0.01...
# Fitting model LightFM_warp_64_3_0.5...
# Fitting model LightFM_warp_64_3_0.1...
# Fitting model LightFM_warp_64_3_0.01...
# Fitting model LightFM_warp_64_5_0.5...
# Fitting model LightFM_warp_64_5_0.1...
# Fitting model LightFM_warp_64_5_0.01...
# Fitting model LightFM_warp_64_7_0.5...
# Fitting model LightFM_warp_64_7_0.1...
# Fitting model LightFM_warp_64_7_0.01...
# Fitting model LightFM_warp_128_3_0.5...
# Fitting model LightFM_warp_128_3_0.1...
# Fitting model LightFM_warp_128_3_0.01...
# Fitting model LightFM_warp_128_5_0.5...
# Fitting model LightFM_warp_128_5_0.1...
# Fitting model LightFM_warp_128_5_0.01...
# Fitting model LightFM_warp_128_7_0.5...
# Fitting model LightFM_warp_128_7_0.1...
# Fitting model LightFM_warp_128_7_0.01...
# Fitting model LightFM_warp_256_3_0.5...
# Fitting model LightFM_warp_256_3_0.1...
# Fitting model LightFM_warp_256_3_0.01...
# Fitting model LightFM_warp_256_5_0.5...
# Fitting model LightFM_warp_256_5_0.1...
# Fitting model LightFM_warp_256_5_0.01...
# Fitting model LightFM_warp_256_7_0.5...
# Fitting model LightFM_warp_256_7_0.1...
# Fitting model LightFM_warp_256_7_0.01...
# Fitting model popular...
# Fitting model ALS_64_3...
# Fitting model ALS_64_5...
# Fitting model ALS_64_7...
# Fitting model ALS_128_3...
# Fitting model ALS_128_5...
# Fitting model ALS_128_7...
# Fitting model ALS_256_3...
# Fitting model ALS_256_5...
# Fitting model ALS_256_7...
# Fitting model LightFM_logistic_64_3_0.5...
# Fitting model LightFM_logistic_64_3_0.1...
# Fitting model LightFM_logistic_64_3_0.01...
# Fitting model LightFM_logistic_64_5_0.5...
# Fitting model LightFM_logistic_64_5_0.1...
# Fitting model LightFM_logistic_64_5_0.01...
# Fitting model LightFM_logistic_64_7_0.5...
# Fitting model LightFM_logistic_64_7_0.1...
# Fitting model LightFM_logistic_64_7_0.01...
# Fitting model LightFM_logistic_128_3_0.5...
# Fitting model LightFM_logistic_128_3_0.1...
# Fitting model LightFM_logistic_128_3_0.01...
# Fitting model LightFM_logistic_128_5_0.5...
# Fitting model LightFM_logistic_128_5_0.1...
# Fitting model LightFM_logistic_128_5_0.01...
# Fitting model LightFM_logistic_128_7_0.5...
# Fitting model LightFM_logistic_128_7_0.1...
# Fitting model LightFM_logistic_128_7_0.01...
# Fitting model LightFM_logistic_256_3_0.5...
# Fitting model LightFM_logistic_256_3_0.1...
# Fitting model LightFM_logistic_256_3_0.01...
# Fitting model LightFM_logistic_256_5_0.5...
# Fitting model LightFM_logistic_256_5_0.1...
# Fitting model LightFM_logistic_256_5_0.01...
# Fitting model LightFM_logistic_256_7_0.5...
# Fitting model LightFM_logistic_256_7_0.1...
# Fitting model LightFM_logistic_256_7_0.01...
# Fitting model LightFM_bpr_64_3_0.5...
# Fitting model LightFM_bpr_64_3_0.1...
# Fitting model LightFM_bpr_64_3_0.01...
# Fitting model LightFM_bpr_64_5_0.5...
# Fitting model LightFM_bpr_64_5_0.1...
# Fitting model LightFM_bpr_64_5_0.01...
# Fitting model LightFM_bpr_64_7_0.5...
# Fitting model LightFM_bpr_64_7_0.1...
# Fitting model LightFM_bpr_64_7_0.01...
# Fitting model LightFM_bpr_128_3_0.5...
# Fitting model LightFM_bpr_128_3_0.1...
# Fitting model LightFM_bpr_128_3_0.01...
# Fitting model LightFM_bpr_128_5_0.5...
# Fitting model LightFM_bpr_128_5_0.1...
# Fitting model LightFM_bpr_128_5_0.01...
# Fitting model LightFM_bpr_128_7_0.5...
# Fitting model LightFM_bpr_128_7_0.1...
# Fitting model LightFM_bpr_128_7_0.01...
# Fitting model LightFM_bpr_256_3_0.5...
# Fitting model LightFM_bpr_256_3_0.1...
# Fitting model LightFM_bpr_256_3_0.01...
# Fitting model LightFM_bpr_256_5_0.5...
# Fitting model LightFM_bpr_256_5_0.1...
# Fitting model LightFM_bpr_256_5_0.01...
# Fitting model LightFM_bpr_256_7_0.5...
# Fitting model LightFM_bpr_256_7_0.1...
# Fitting model LightFM_bpr_256_7_0.01...
# Fitting model LightFM_warp_64_3_0.5...
# Fitting model LightFM_warp_64_3_0.1...
# Fitting model LightFM_warp_64_3_0.01...
# Fitting model LightFM_warp_64_5_0.5...
# Fitting model LightFM_warp_64_5_0.1...
# Fitting model LightFM_warp_64_5_0.01...
# Fitting model LightFM_warp_64_7_0.5...
# Fitting model LightFM_warp_64_7_0.1...
# Fitting model LightFM_warp_64_7_0.01...
# Fitting model LightFM_warp_128_3_0.5...
# Fitting model LightFM_warp_128_3_0.1...
# Fitting model LightFM_warp_128_3_0.01...
# Fitting model LightFM_warp_128_5_0.5...
# Fitting model LightFM_warp_128_5_0.1...
# Fitting model LightFM_warp_128_5_0.01...
# Fitting model LightFM_warp_128_7_0.5...
# Fitting model LightFM_warp_128_7_0.1...
# Fitting model LightFM_warp_128_7_0.01...
# Fitting model LightFM_warp_256_3_0.5...
# Fitting model LightFM_warp_256_3_0.1...
# Fitting model LightFM_warp_256_3_0.01...
# Fitting model LightFM_warp_256_5_0.5...
# Fitting model LightFM_warp_256_5_0.1...
# Fitting model LightFM_warp_256_5_0.01...
# Fitting model LightFM_warp_256_7_0.5...
# Fitting model LightFM_warp_256_7_0.1...
# Fitting model LightFM_warp_256_7_0.01...
# CPU times: user 2d 22h 59min 22s, sys: 5min 40s, total: 2d 23h 5min 2s
# Wall time: 3h 54min 3s

# %%
import gc

del items_fold, user_features, item_features

gc.collect()
# Out:
# 0

# %%
df_metrics = pd.DataFrame(results)
df_metrics.groupby('model').mean()[metrics.keys()].style.highlight_max(color='green', axis=0)
# Out:
# <style type="text/css">
# #T_78f97_row72_col2, #T_78f97_row81_col0, #T_78f97_row81_col3, #T_78f97_row81_col5, #T_78f97_row81_col6, #T_78f97_row81_col7, #T_78f97_row81_col8, #T_78f97_row90_col1, #T_78f97_row90_col4 {
#   background-color: green;
# }
# </style>
# <table id="T_78f97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78f97_level0_col0" class="col_heading level0 col0" >Precision@1</th>
#       <th id="T_78f97_level0_col1" class="col_heading level0 col1" >Precision@5</th>
#       <th id="T_78f97_level0_col2" class="col_heading level0 col2" >Precision@10</th>
#       <th id="T_78f97_level0_col3" class="col_heading level0 col3" >Recall@1</th>
#       <th id="T_78f97_level0_col4" class="col_heading level0 col4" >Recall@5</th>
#       <th id="T_78f97_level0_col5" class="col_heading level0 col5" >Recall@10</th>
#       <th id="T_78f97_level0_col6" class="col_heading level0 col6" >MAP@1</th>
#       <th id="T_78f97_level0_col7" class="col_heading level0 col7" >MAP@5</th>
#       <th id="T_78f97_level0_col8" class="col_heading level0 col8" >MAP@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78f97_level0_row0" class="row_heading level0 row0" >ALS_128_3</th>
#       <td id="T_78f97_row0_col0" class="data row0 col0" >0.059086</td>
#       <td id="T_78f97_row0_col1" class="data row0 col1" >0.037951</td>
#       <td id="T_78f97_row0_col2" class="data row0 col2" >0.024097</td>
#       <td id="T_78f97_row0_col3" class="data row0 col3" >0.034001</td>
#       <td id="T_78f97_row0_col4" class="data row0 col4" >0.103684</td>
#       <td id="T_78f97_row0_col5" class="data row0 col5" >0.126365</td>
#       <td id="T_78f97_row0_col6" class="data row0 col6" >0.034001</td>
#       <td id="T_78f97_row0_col7" class="data row0 col7" >0.060056</td>
#       <td id="T_78f97_row0_col8" class="data row0 col8" >0.063658</td>
#     </tr>
#     <tr>
#       <th id="T_78f97_level0_row1" class="row_heading level0 row1" >ALS_128_5</th>
#       <td id="T_78f97_row1_col0" class="data row1 col0" >0.059549</td>
#       <td id="T_78f97_row1_col1" class="data row1 col1" >0.037994</td>
#       <td id="T_78f97_row1_col2" class="data row1 col2" >0.024179</td>
#       <td id="T_78f97_row1_col3" class="data row1 col3" >0.034317</td>
#       <td id="T_78f97_row1_col4" class="data row1 col4" >0.103877</td>
#       <td id="T_78f97_row1_col5" class="data row1 col5" >0.126745</td>
#       <td id="T_78f97_row1_col6" class="data row1 col6" >0.034317</td>
#       <td id="T_78f97_row1_col7" class="data row1 col7" >0.060257</td>
#       <td id="T_78f97_row1_col8" class="data row1 col8" >0.063886</td>
#     </tr>
#     <tr>
#       <th id="T_78f97_level0_row2" class="row_heading level0 row2" >ALS_128_7</th>
#       <td id="T_78f97_row2_col0" class="data row2 col0" >0.064535</td>
#       <td id="T_78f97_row2_col1" class="data row2 col1" >0.039931</td>
#       <td id="T_78f97_row2_col2" class="data row2 col2" >0.025420</td>
#       <td id="T_78f97_row2_col3" class="data row2 col3" >0.037801</td>
#       <td id="T_78f97_row2_col4" class="data row2 col4" >0.110362</td>
#       <td id="T_78f97_row2_col5" class="data row2 col5" >0.134816</td>
#       <td id="T_78f97_row2_col6" class="data row2 col6" >0.037801</td>
#       <td id="T_78f97_row2_col7" class="data row2 col7" >0.064981</td>
#       <td id="T_78f97_row2_col8" class="data row2 col8" >0.068843</td>
#     </tr>
#     <tr>
#       <th id="T_78f97_level0_row3" class="row_heading level0 row3" >ALS_256_3</th>
#       <td id="T_78f97_row3_col0" class="data row3 col0" >0.059073</td>
#       <td id="T_78f97_row3_col1" class="data row3 col1" >0.037945</td>
#       <td id="T_78f97_row3_col2" class="data row3 col2" >0.024103</td>
#       <td id="T_78f97_row3_col3" class="data row3 col3" >0.033996</td>
#       <td id="T_78f97_row3_col4" class="data row3 col4" >0.103675</td>
#       <td id="T_78f97_row3_col5" class="data row3 col5" >0.126371</td>
#       <td id="T_78f97_row3_col6" class="data row3 col6" >0.033996</td>
#       <td id="T_78f97_row3_col7" class="data row3 col7" >0.060047</td>
#       <td id="T_78f97_row3_col8" class="data row3 col8" >0.063651</td>
#     </tr>
#     <tr>
#       <th id="T_78f97_level0_row4" class="row_heading level0 row4" >ALS_256_5</th>
#       <td id="T_78f97_row4_col0" class="data row4 col0" >0.059442</td>
#       <td id="T_78f97_row4_col1" class="data row4 col1" >0.037976</td>
#       <td id="T_78f97_row4_col2" class="data row4 col2" >0.024167</td>
#       <td id="T_78f97_row4_col3" class="data row4 col3" >0.034216</td>
#       <td id="T_78f97_row4_col4" class="data row4 col4" >0.103784</td>
#       <td id="T_78f97_row4_col5" class="data row4 col5" >0.126637</td>
#       <td id="T_78f97_row4_col6" class="data row4 col6" >0.034216</td>
#       <td id="T_78f97_row4_col7" class="data row4 col7" >0.060174</td>
#       <td id="T_78f97_row4_col8" class="data row4 col8" >0.063801</td>
#     </tr>
#     <tr>
#       <th id="T_78f97_level0_row5" class="row_heading level0 row5" >ALS_256_7</th>
#       <td id="T_78f97_row5_col0" class="data row5 col0" >0.060714</td>
#       <td id="T_78f97_row5_col1" class="data row5 col1" >0.038442</td>
#       <td id="T_78f97_row5_col2" class="data row5 col2" >0.024524</td>
#       <td id="T_78f97_row5_col3" class="data row5 col3" >0.034993</td>
#       <td id="T_78f97_row5_col4" class="data row5 col4" >0.105367</td>
#       <td id="T_78f97_row5_col5" class="data row5 col5" >0.128875</td>
#       <td id="T_78f97_row5_col6" class="data row5 col6" >0.034993</td>
#       <td id="T_78f97_row5_col7" class="data row5 col7" >0.061257</td>
#       <td id="T_78f97_row5_col8" class="data row5 col8" >0.064974</td>
#     </tr>
#     <tr>
#       <th id="T_78f97_level0_row6" class="row_heading level0 row6" >ALS_64_3</th>
#       <td id="T_78f97_row6_col0" class="data row6 col0" >0.059130</td>
#       <td id="T_78f97_row6_col1" class="data row6 col1" >0.037957</td>
#       <td id="T_78f97_row6_col2" class="data row6 col2" >0.024115</td>
#       <td id="T_78f97_row6_col3" class="data row6 col3" >0.034031</td>
#       <td id="T_78f97_row6_col4" class="data row6 col4" >0.103728</td>
#       <td id="T_78f97_row6_col5" class="data row6 col5" >0.126460</td>
#       <td id="T_78f97_row6_col6" class="data row6 col6" >0.034031</td>
#       <td id="T_78f97_row6_col7" class="data row6 col7" >0.060088</td>
#       <td id="T_78f97_row6_col8" class="data row6 col8" >0.063700</td>
#     </tr>
#     <tr>
#       <th id="T_78f97_level0_row7" class="row_heading level0 row7" >ALS_64_5</th>
#       <td id="T_78f97_row7_col0" class="data row7 col0" >0.059875</td>
#       <td id="T_78f97_row7_col1" class="data row7 col1" >0.038096</td>
#       <td id="T_78f97_row7_col2" class="data row7 col2" >0.024252</td>
#       <td id="T_78f97_row7_col3" class="data row7 col3" >0.034484</td>
#       <td id="T_78f97_row7_col4" class="data row7 col4" >0.104225</td>
#       <td id="T_78f97_row7_col5" class="data row7 col5" >0.127182</td>
#       <td id="T_78f97_row7_col6" class="data row7 col6" >0.034484</td>
#       <td id="T_78f97_row7_col7" class="data row7 col7" >0.060463</td>
#       <td id="T_78f97_row7_col8" class="data row7 col8" >0.064105</td>
#     </tr>
#     <tr>
#       <th id="T_78f97_level0_row8" class="row_heading level0 row8" >ALS_64_7</th>
#       <td id="T_78f97_row8_col0" class="data row8 col0" >0.069145</td>
#       <td id="T_78f97_row8_col1" class="data row8 col1" >0.041787</td>
#       <td id="T_78f97_row8_col2" class="data row8 col2" >0.026506</td>
#       <td id="T_78f97_row8_col3" class="data row8 col3" >0.040807</td>
#       <td id="T_78f97_row8_col4" class="data row8 col4" >0.116153</td>
#       <td id="T_78f97_row8_col5" class="data row8 col5" >0.141487</td>

# %% [markdown]
# # Train full model

# %%
users = pd.read_csv('data_original/users.csv')
items = pd.read_csv('data_original/items.csv')
interactions = pd.read_csv('data_original/interactions.csv')

users.fillna('Unknown', inplace=True)

# %%
interactions.drop(interactions[interactions['last_watch_dt'].str.len() != 10].index, inplace=True)
interactions[Columns.Datetime] = pd.to_datetime(interactions['last_watch_dt'], format='%Y-%m-%d')
max_date = interactions[Columns.Datetime].max()
interactions = interactions[interactions.watched_pct > 0]
interactions[Columns.Weight] = np.where(interactions['watched_pct'] > 10, 5, 1) # MB drop 0 pct

interactions = Interactions(interactions)
interactions.df.head()
# Out:
#    user_id  item_id last_watch_dt  total_dur  watched_pct   datetime  weight
# 0   176549     9506    2021-05-11       4250         72.0 2021-05-11     5.0
# 1   699317     1659    2021-05-29       8317        100.0 2021-05-29     5.0
# 3   864613     7638    2021-07-05      14483        100.0 2021-07-05     5.0
# 4   964868     9506    2021-04-30       6725        100.0 2021-04-30     5.0
# 5  1032142     6686    2021-05-13      11286        100.0 2021-05-13     5.0

# %%
K_RECOS = 10
RANDOM_STATE = 42
NUM_THREADS = 24
N_FACTORS = 64

N_EPOCHS = 3 # Lightfm
USER_ALPHA = 0 # Lightfm
ITEM_ALPHA = 0 # Lightfm
LEARNING_RATE = 0.01 # Lightfm

# %%
# LightFM_warp_64_3_0.01
model = LightFMWrapperModel(
    LightFM(
        no_components=N_FACTORS, 
        loss='warp', 
        random_state=RANDOM_STATE,
        learning_rate=LEARNING_RATE,
        user_alpha=USER_ALPHA,
        item_alpha=ITEM_ALPHA),
    epochs=N_EPOCHS,
    num_threads=NUM_THREADS)

# %%
users = users.loc[users[Columns.User].isin(interactions.df[Columns.User])].copy()
user_features_frames = []
for feature in ["sex", "age", "income"]:
    feature_frame = users.reindex(columns=[Columns.User, feature])
    feature_frame.columns = ["id", "value"]
    feature_frame["feature"] = feature
    user_features_frames.append(feature_frame)
user_features = pd.concat(user_features_frames)

# %%
items = items.loc[items[Columns.Item].isin(interactions.df[Columns.Item])].copy()
# Explode genres to flatten table
items["genre"] = items["genres"].str.lower().str.replace(", ", ",", regex=False).str.split(",")
genre_feature = items[["item_id", "genre"]].explode("genre")
genre_feature.columns = ["id", "value"]
genre_feature["feature"] = "genre"

content_feature = items.reindex(columns=[Columns.Item, "content_type"])
content_feature.columns = ["id", "value"]
content_feature["feature"] = "content_type"
item_features = pd.concat((genre_feature, content_feature))

# %%
dataset = Dataset.construct(
    interactions_df=interactions.df,
    user_features_df=user_features,
    cat_user_features=["sex", "age", "income"],
    item_features_df=item_features,
    cat_item_features=["genre", "content_type"],
)

# %%
model.fit(dataset)

# %%
user_embeddings, item_embeddings = model.get_vectors(dataset)

# %%
user_embeddings.shape, item_embeddings.shape
# Out:
# ((862388, 66), (14701, 66))

# %%
def augment_inner_product(factors):
    normed_factors = np.linalg.norm(factors, axis=1)
    max_norm = normed_factors.max()
    
    extra_dim = np.sqrt(max_norm ** 2 - normed_factors ** 2).reshape(-1, 1)
    augmented_factors = np.append(factors, extra_dim, axis=1)
    return max_norm, augmented_factors

max_norm, augmented_item_embeddings = augment_inner_product(item_embeddings)
augmented_item_embeddings.shape
# Out:
# (14701, 67)

# %%
extra_zero = np.zeros((user_embeddings.shape[0], 1))
augmented_user_embeddings = np.append(user_embeddings, extra_zero, axis=1)
augmented_user_embeddings.shape
# Out:
# (862388, 67)

# %%
# Set index parameters
# These are the most important ones
M = 48
efC = 100

num_threads = 4
index_time_params = {'M': M, 'indexThreadQty': num_threads, 'efConstruction': efC, 'post' : 0}
print('Index-time parameters', index_time_params)
# Out:
# Index-time parameters {'M': 48, 'indexThreadQty': 4, 'efConstruction': 100, 'post': 0}

# %%
# Number of neighbors 
K=10

# %%
# Space name should correspond to the space name 
# used for brute-force search
space_name='negdotprod'

# %%
# Intitialize the library, specify the space, the type of the vector and add data points 
index = nmslib.init(method='hnsw', space=space_name, data_type=nmslib.DataType.DENSE_VECTOR) 
index.addDataPointBatch(augmented_item_embeddings)
# Out:
# 14701

# %%
# Create an index
index_time_params = {'M': M, 'indexThreadQty': num_threads, 'efConstruction': efC}
index.createIndex(index_time_params)
print('Index-time parameters', index_time_params)
# Out:
# Index-time parameters {'M': 48, 'indexThreadQty': 4, 'efConstruction': 100}

# %%
# Setting query-time parameters
efS = 100
query_time_params = {'efSearch': efS}
print('Setting query-time parameters', query_time_params)
index.setQueryTimeParams(query_time_params)
# Out:
# Setting query-time parameters {'efSearch': 100}

# %%
query_matrix = augmented_user_embeddings[:1000, :]

# %%
import time
# Querying
query_qty = query_matrix.shape[0]
start = time.time() 
nbrs = index.knnQueryBatch(query_matrix, k = K, num_threads = num_threads)
end = time.time() 
print('kNN time total=%f (sec), per query=%f (sec), per query adjusted for thread number=%f (sec)' % 
      (end-start, float(end-start)/query_qty, num_threads*float(end-start)/query_qty))
# Out:
# kNN time total=0.005046 (sec), per query=0.000005 (sec), per query adjusted for thread number=0.000020 (sec)

# %%
list(index.knnQuery(query_matrix[0], k=K)[0])
# Out:
# [9, 210, 29, 15, 325, 44, 74, 150, 541, 640]

# %%
index.saveIndex("light_fm", save_data=True)

# %%
import pickle

with open("int_u_id2vec.pkl", "wb") as f:
    pickle.dump(augmented_user_embeddings, f)

# %%
ext_u_id2int_u_id = {}

for int_u_id, ext_u_id in enumerate(dataset.user_id_map.external_ids):
    ext_u_id2int_u_id[ext_u_id] = int_u_id

# %%
with open("ext_u_id2int_u_id.pkl", "wb") as f:
    pickle.dump(ext_u_id2int_u_id, f)

# %%
int_i_id2ext_i_id = {}

for int_i_id, ext_i_id in enumerate(dataset.item_id_map.external_ids):
    int_i_id2ext_i_id[int_i_id] = ext_i_id

# %%
with open("int_i_id2ext_i_id.pkl", "wb") as f:
    pickle.dump(int_i_id2ext_i_id, f)

# %%
test = nmslib.init(
            method='hnsw', 
            space='negdotprod', 
            data_type=nmslib.DataType.DENSE_VECTOR)

nmslib.loadIndex(test, "light_fm")

# %%
list(test.knnQuery(query_matrix[0], k=K)[0])
# Out:
# [9, 210, 29, 15, 325, 44, 74, 150, 541, 640]
